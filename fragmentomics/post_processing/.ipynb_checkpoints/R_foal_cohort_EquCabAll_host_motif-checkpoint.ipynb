# %%
require("Hmisc")
require("dplyr")
require("profvis")
require("R.utils")
require("Biostrings")
require("data.table")
require("ggplot2")

# %%
foal_nonMT_IS_meta <- fread(file = "../../output/04_fragmentomics/library_prep_comparison_EquCabAll_nonMT_IS_meta.csv") %>% as.data.frame() %>% 
    mutate(across(-c(TLEN, Count), ~ as.factor(.)))

foal_nonMT_IS_meta %>% 
    filter(!grepl(sample_id, pattern = "^[P/N]")) %>% 
    #filter(grepl(side, pattern = "neg")) %>% 
    mutate(TLEN = abs(TLEN)) %>% 
    #filter(sample_id == "2105643Mod") %>% 
    filter(TLEN < 300) %>% 
    mutate(read = substring(side, 0, 2)) %>% 
    #filter(read == "R1") %>% 
    group_by(sample_id, read) %>% 
    summarise(sCount = sum(Count, na.rm = TRUE)) 

options(repr.plot.width=14, repr.plot.height=5)
foal_nonMT_IS_meta %>% 
    filter(!grepl(sample_id, pattern = "^[P/N]")) %>% 
    #filter(grepl(side, pattern = "neg")) %>% 
    mutate(TLEN = abs(TLEN)) %>% 
    #filter(sample_id == "2105643Mod") %>% 
    filter(TLEN < 300) %>% 
    mutate(read = substring(side, 0, 2)) %>% 
    #filter(read == "R1") %>% 
    group_by(sample_id, TLEN, read) %>%
    summarise(sCount = sum(Count, na.rm = TRUE)) %>%     
    group_by(read) %>% 
    mutate(nsCount = sCount/sum(sCount)) %>% 
    ggplot(aes(x = TLEN, y = nsCount, col = sample_id)) + 
        geom_line() + facet_grid(cols = vars(read)) + theme_bw()
# Out:
# `summarise()` has grouped output by 'sample_id'. You can override using the `.groups` argument.
#   sample_id        read sCount
# 1 2105643Mod       R1   127686
# 2 2105643Mod       R2   127686
# 3 2105643ModBBSS   R1   110268
# 4 2105643ModBBSS   R2   110268
# 5 2105643Small     R1   120988
# 6 2105643Small     R2   120988
# 7 2105643SmallBBSS R1   181266
# 8 2105643SmallBBSS R2   181266
# `summarise()` has grouped output by 'sample_id', 'TLEN'. You can override using the `.groups` argument.
# plot without title
